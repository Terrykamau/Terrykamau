# %% [markdown]
# <a href="https://colab.research.google.com/github/Terrykamau/Terrykamau/blob/main/data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/Customer Call List (1).xlsx')

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df["Last_Name"]=df["Last_Name"].str.strip("123,_/")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123-/64-3/97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876-|67-8|34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-|67-8|34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry   ...Potter
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876-|67-8|34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123-/64-3/97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('[^a-zA-Z0-9]','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123-545-5421
# 1         1002       Abed       Nadir  123/643/9775
# 2         1003     Walter       White           NaN
# 3         1004     Dwight     Schrute  123-543-2345
# 4         1005        Jon        Snow  876|678|3469
# 5         1006        Ron     Swanson  304-762-2467
# 6         1007       Jeff      Winger           NaN
# 7         1008   Sherlock      Holmes  876|678|3469
# 8         1009    Gandalf         NaN           N/a
# 9         1010      Peter      Parker  123-545-5421
# 10        1011    Samwise      Gamgee           NaN
# 11        1012      Harry   ...Potter           NaN
# 12        1013        Don      Draper  123-543-2345
# 13        1014     Leslie       Knope  876|678|3469
# 14        1015       Toby  Flenderson  304-762-2467
# 15        1016        Ron     Weasley  123-545-5421
# 16        1017   Michael        Scott  123/643/9775
# ...

# %%
#df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' x[6:10])

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda x: str(x))

# %%
df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
# Out:
# 0     123--54-5-54
# 1     123-/64-3/97
# 2            nan--
# 3     123--54-3-23
# 4     876-|67-8|34
# 5     304--76-2-24
# 6            nan--
# 7     876-|67-8|34
# 8            N/a--
# 9     123--54-5-54
# 10           nan--
# 11           nan--
# 12    123--54-3-23
# 13    876-|67-8|34
# 14    304--76-2-24
# 15    123--54-5-54
# 16    123-/64-3/97
# 17           nan--
# 18           N/a--
# 19    876-|67-8|34
# 20    876-|67-8|34
# Name: Phone_Number, dtype: object

# %%
df["Phone_Number"]=df["Phone_Number"].apply(lambda x: x[0:3] + '-' + x[3:6] + '-' + x[6:10])
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123-/64-3/97
# 2         1003     Walter       White         nan--
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876-|67-8|34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger         nan--
# 7         1008   Sherlock      Holmes  876-|67-8|34
# 8         1009    Gandalf         NaN         N/a--
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee         nan--
# 11        1012      Harry   ...Potter         nan--
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876-|67-8|34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123-/64-3/97
# ...

# %%
df["Phone_Number"]=df["Phone_Number"].str.replace('nan--','')
df["Phone_Number"]=df["Phone_Number"].str.replace('N/a--','')
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123-/64-3/97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876-|67-8|34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-|67-8|34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry   ...Potter
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876-|67-8|34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123-/64-3/97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df=df.drop(columns="Not_Useful_Column")
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123-/64-3/97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876-|67-8|34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-|67-8|34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry   ...Potter
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876-|67-8|34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123-/64-3/97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df[["Street_Address","State","zip_Code"]]=df["Address"].str.split(',',expand=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number  \
# 0         1001      Frodo     Baggins  123--54-5-54
# 1         1002       Abed       Nadir  123-/64-3/97
# 2         1003     Walter       White
# 3         1004     Dwight     Schrute  123--54-3-23
# 4         1005        Jon        Snow  876-|67-8|34
# 5         1006        Ron     Swanson  304--76-2-24
# 6         1007       Jeff      Winger
# 7         1008   Sherlock      Holmes  876-|67-8|34
# 8         1009    Gandalf         NaN
# 9         1010      Peter      Parker  123--54-5-54
# 10        1011    Samwise      Gamgee
# 11        1012      Harry   ...Potter
# 12        1013        Don      Draper  123--54-3-23
# 13        1014     Leslie       Knope  876-|67-8|34
# 14        1015       Toby  Flenderson  304--76-2-24
# 15        1016        Ron     Weasley  123--54-5-54
# 16        1017   Michael        Scott  123-/64-3/97
# 17        1018      Clark        Kent
# 18        1019      Creed      Braton
# ...

# %%
df["Do_Not_Contact"]=df["Paying Customer"].str.replace('Yes','Y')
df["Do_Not_Contact"]=df["Paying Customer"].str.replace('No','N')
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.fillna('')
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf                        N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
for x in df.index:
  if df.loc[x,"Do_Not_Contact"]=='Y':
    df.drop(x,inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  123-/64-3/97   93 West Main Street
# 2         1003     Walter       White                  298 Drugs Driveway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-|67-8|34         98 Clue Drive
# 14        1015       Toby  Flenderson  304--76-2-24         214 HR Avenue
# 15        1016        Ron     Weasley  123--54-5-54  2395 Hogwarts Avenue
# 18        1019      Creed      Braton                                 N/a
#
#    Paying Customer Do_Not_Contact        Street_Address State zip_Code
# 1                N              N   93 West Main Street
# 2                N              N    298 Drugs Driveway
# 6                N              N     1209 South Street
# 7                N              N         98 Clue Drive
# 14               N              N         214 HR Avenue
# ...

# %%
for x in df.index:
  if df.loc[x,"Do_Not_Contact"]=='':
    df.drop(x,inplace=True)
df
# Out:
#     CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 1         1002       Abed       Nadir  123-/64-3/97   93 West Main Street
# 2         1003     Walter       White                  298 Drugs Driveway
# 6         1007       Jeff      Winger                   1209 South Street
# 7         1008   Sherlock      Holmes  876-|67-8|34         98 Clue Drive
# 14        1015       Toby  Flenderson  304--76-2-24         214 HR Avenue
# 15        1016        Ron     Weasley  123--54-5-54  2395 Hogwarts Avenue
# 18        1019      Creed      Braton                                 N/a
#
#    Paying Customer Do_Not_Contact        Street_Address State zip_Code
# 1                N              N   93 West Main Street
# 2                N              N    298 Drugs Driveway
# 6                N              N     1209 South Street
# 7                N              N         98 Clue Drive
# 14               N              N         214 HR Avenue
# ...

# %%
df.reset_index(drop=True)
# Out:
#    CustomerID First_Name   Last_Name  Phone_Number               Address  \
# 0        1002       Abed       Nadir  123-/64-3/97   93 West Main Street
# 1        1003     Walter       White                  298 Drugs Driveway
# 2        1007       Jeff      Winger                   1209 South Street
# 3        1008   Sherlock      Holmes  876-|67-8|34         98 Clue Drive
# 4        1015       Toby  Flenderson  304--76-2-24         214 HR Avenue
# 5        1016        Ron     Weasley  123--54-5-54  2395 Hogwarts Avenue
# 6        1019      Creed      Braton                                 N/a
#
#   Paying Customer Do_Not_Contact        Street_Address State zip_Code
# 0               N              N   93 West Main Street
# 1               N              N    298 Drugs Driveway
# 2               N              N     1209 South Street
# 3               N              N         98 Clue Drive
# 4               N              N         214 HR Avenue
# ...
