# %% [markdown]
# <a href="https://colab.research.google.com/github/Terrykamau/Terrykamau/blob/main/group_by_%2B_aggregate_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/onlinefoods.csv')

# %%
df
# Out:
#      Age  Gender     Marital Status      Occupation   Monthly Income  \
# 0     20  Female             Single         Student        No Income
# 1     24  Female             Single         Student   Below Rs.10000
# 2     22    Male             Single         Student   Below Rs.10000
# 3     22  Female             Single         Student        No Income
# 4     22    Male             Single         Student   Below Rs.10000
# 5     27  Female            Married        Employee  More than 50000
# 6     22    Male             Single         Student        No Income
# 7     24  Female             Single         Student        No Income
# 8     23  Female             Single         Student        No Income
# 9     23  Female             Single         Student        No Income
# 10    22  Female             Single         Student        No Income
# 11    23    Male             Single         Student   Below Rs.10000
# 12    23    Male             Single         Student        No Income
# ...

# %%
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
df.groupby('Educational Qualifications')

# %%
group_by_frame=df.groupby('Educational Qualifications')

# %%
group_by_frame.describe()
# Out:
#                               Age                                         \
#                             count       mean       std   min   25%   50%
# Educational Qualifications
# Graduate                    177.0  24.655367  3.382758  18.0  22.0  24.0
# Ph.D                         23.0  26.608696  3.115053  21.0  24.5  26.0
# Post Graduate               174.0  24.034483  1.979363  20.0  23.0  24.0
# School                       12.0  28.000000  3.692745  22.0  25.0  30.0
# Uneducated                    2.0  31.000000  1.414214  30.0  30.5  31.0
#
#                                        Family size                           \
#                              75%   max       count      mean       std  min
# Educational Qualifications
# Graduate                    27.0  32.0       177.0  3.276836  1.405013  1.0
# Ph.D                        28.0  33.0        23.0  3.695652  1.258960  1.0
# Post Graduate               25.0  32.0       174.0  3.149425  1.263345  1.0
# ...

# %%
df.groupby('Educational Qualifications').count()
# Out:
#                             Age  Gender  Marital Status  Occupation  \
# Educational Qualifications
# Graduate                    177     177             177         177
# Ph.D                         23      23              23          23
# Post Graduate               174     174             174         174
# School                       12      12              12          12
# Uneducated                    2       2               2           2
#
#                             Monthly Income  Family size  latitude  longitude  \
# Educational Qualifications
# Graduate                               177          177       177        177
# Ph.D                                    23           23        23         23
# Post Graduate                          174          174       174        174
# School                                  12           12        12         12
# Uneducated                               2            2         2          2
#
# ...

# %%
df.groupby('Educational Qualifications').max()
# Out:
#                             Age Gender Marital Status      Occupation  \
# Educational Qualifications
# Graduate                     32   Male         Single         Student
# Ph.D                         33   Male         Single         Student
# Post Graduate                32   Male         Single         Student
# School                       32   Male         Single  Self Employeed
# Uneducated                   32   Male        Married  Self Employeed
#
#                            Monthly Income  Family size  latitude  longitude  \
# Educational Qualifications
# Graduate                        No Income            6   13.0809    77.7582
# Ph.D                            No Income            6   13.0626    77.7500
# Post Graduate                   No Income            6   13.1020    77.7582
# School                          No Income            6   13.0626    77.6713
# Uneducated                      No Income            4   13.0140    77.6068
#
# ...

# %%
df.groupby('Educational Qualifications').min()
# Out:
#                             Age  Gender Marital Status  Occupation  \
# Educational Qualifications
# Graduate                     18  Female        Married    Employee
# Ph.D                         21  Female        Married    Employee
# Post Graduate                20  Female        Married    Employee
# School                       22  Female        Married  House wife
# Uneducated                   30  Female        Married  House wife
#
#                              Monthly Income  Family size  latitude  longitude  \
# Educational Qualifications
# Graduate                     10001 to 25000            1   12.8652    77.4842
# Ph.D                         10001 to 25000            1   12.9048    77.5284
# Post Graduate                10001 to 25000            1   12.8834    77.4921
# School                       10001 to 25000            2   12.9251    77.4992
# Uneducated                  More than 50000            3   12.9662    77.5658
#
# ...

# %%
df.groupby('Educational Qualifications').sum()
# Out:
#                              Age  \
# Educational Qualifications
# Graduate                    4364
# Ph.D                         612
# Post Graduate               4182
# School                       336
# Uneducated                    62
#
#                                                                        Gender  \
# Educational Qualifications
# Graduate                    FemaleFemaleMaleMaleFemaleMaleFemaleMaleFemale...
# Ph.D                        MaleMaleFemaleMaleFemaleMaleMaleMaleMaleMaleMa...
# Post Graduate               FemaleMaleMaleFemaleFemaleFemaleFemaleFemaleMa...
# School                      FemaleFemaleMaleFemaleMaleFemaleMaleMaleFemale...
# Uneducated                                                         MaleFemale
#
#                                                                Marital Status  \
# Educational Qualifications
# Graduate                    SingleSingleSingleSingleSingleSingleSingleSing...
# ...

# %%
df.groupby('Educational Qualifications').agg({"Occupation":['count','max'],"Monthly Income":['min','max']})
# Out:
#                            Occupation                   Monthly Income  \
#                                 count             max              min
# Educational Qualifications
# Graduate                          177         Student   10001 to 25000
# Ph.D                               23         Student   10001 to 25000
# Post Graduate                     174         Student   10001 to 25000
# School                             12  Self Employeed   10001 to 25000
# Uneducated                          2  Self Employeed  More than 50000
#
#
#                                   max
# Educational Qualifications
# Graduate                    No Income
# Ph.D                        No Income
# Post Graduate               No Income
# School                      No Income
# Uneducated                  No Income

# %%
df
# Out:
#      Age  Gender     Marital Status      Occupation   Monthly Income  \
# 0     20  Female             Single         Student        No Income
# 1     24  Female             Single         Student   Below Rs.10000
# 2     22    Male             Single         Student   Below Rs.10000
# 3     22  Female             Single         Student        No Income
# 4     22    Male             Single         Student   Below Rs.10000
# 5     27  Female            Married        Employee  More than 50000
# 6     22    Male             Single         Student        No Income
# 7     24  Female             Single         Student        No Income
# 8     23  Female             Single         Student        No Income
# 9     23  Female             Single         Student        No Income
# 10    22  Female             Single         Student        No Income
# 11    23    Male             Single         Student   Below Rs.10000
# 12    23    Male             Single         Student        No Income
# ...

# %%
df.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
df.groupby(['Marital Status','Occupation']).max()
# Out:
#                                   Age  Gender   Monthly Income  \
# Marital Status    Occupation
# Married           Employee         33    Male  More than 50000
#                   House wife       32  Female        No Income
#                   Self Employeed   32    Male  More than 50000
#                   Student          28    Male        No Income
# Prefer not to say Employee         31    Male   Below Rs.10000
#                   House wife       32  Female        No Income
#                   Self Employeed   26    Male  More than 50000
# Single            Employee         29    Male  More than 50000
#                   Self Employeed   29    Male  More than 50000
#                   Student          27    Male        No Income
#
#                                  Educational Qualifications  Family size  \
# Marital Status    Occupation
# Married           Employee                    Post Graduate            6
# ...

# %%
df.groupby(['Marital Status','Occupation']).agg({"Monthly Income":['min','max']})
# Out:
#                                    Monthly Income
#                                               min              max
# Marital Status    Occupation
# Married           Employee         10001 to 25000  More than 50000
#                   House wife            No Income        No Income
#                   Self Employeed   10001 to 25000  More than 50000
#                   Student          Below Rs.10000        No Income
# Prefer not to say Employee         10001 to 25000   Below Rs.10000
#                   House wife            No Income        No Income
#                   Self Employeed  More than 50000  More than 50000
# Single            Employee         10001 to 25000  More than 50000
#                   Self Employeed   10001 to 25000  More than 50000
#                   Student          10001 to 25000        No Income

# %%
df.groupby(['Marital Status','Occupation']).describe()
# Out:
#                                     Age                                    \
#                                   count       mean       std   min    25%
# Marital Status    Occupation
# Married           Employee         65.0  27.938462  2.714987  21.0  26.00
#                   House wife        8.0  30.125000  2.997022  23.0  30.00
#                   Self Employeed   29.0  26.965517  2.382717  22.0  25.00
#                   Student           6.0  25.000000  2.000000  22.0  24.25
# Prefer not to say Employee          7.0  26.714286  3.352327  23.0  24.00
#                   House wife        1.0  32.000000       NaN  32.0  32.00
#                   Self Employeed    4.0  25.500000  1.000000  24.0  25.50
# Single            Employee         46.0  24.630435  2.069446  21.0  23.00
#                   Self Employeed   21.0  25.761905  1.786190  23.0  25.00
#                   Student         201.0  22.746269  1.493418  18.0  22.00
#
# ...
